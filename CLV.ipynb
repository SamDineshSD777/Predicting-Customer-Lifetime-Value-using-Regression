# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load the input data of customer life value fromm a csv file
cust_data = pd.read_csv('/content/WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv')
cust_data.head()

# %%
cd = cust_data.rename(columns={'Customer Lifetime Value':'CLV'})
cd.head()
# Out:
#   Customer       State           CLV Response  Coverage Education  \
# 0  BU79786  Washington   2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona   6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada  12887.431650       No   Premium  Bachelor
# 3  WW63253  California   7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington   2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# ...

# %%
cust_data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
cust_data.isnull().sum()

# %%
res = cust_data.dtypes
res

# %%
a = cust_data.drop(['Customer','Effective To Date'], axis=1)
a
# Out:
#            State  Customer Lifetime Value Response  Coverage Education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      EmploymentStatus Gender  Income Location Code Marital Status  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
for col in a.columns:
    a[col] = lb.fit_transform(a[col])
a
# Out:
#       State  Customer Lifetime Value  Response  Coverage  Education  \
# 0         4                      975         0         0          0
# 1         0                     4659         0         1          0
# 2         2                     6900         0         2          0
# 3         1                     5140         0         0          0
# 4         4                     1058         0         0          0
# ...     ...                      ...       ...       ...        ...
# 9129      1                     7701         0         0          0
# 9130      1                     1390         1         1          1
# 9131      1                     5516         0         1          0
# 9132      1                     5041         0         1          1
# 9133      1                      688         0         1          1
#
#       EmploymentStatus  Gender  Income  Location Code  Marital Status  ...  \
# ...
